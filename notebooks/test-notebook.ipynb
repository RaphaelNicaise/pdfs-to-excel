# %%
import sys
import os
import re
sys.path.insert(0, os.path.abspath('..'))

from pdfquery import PDFQuery
import fitz
import pandas as pd
from utils.utilities import (
    convertir_pdf_a_xml
)
from src.scrap_pdf_AG import (
    check_format,
    get_PESO_BRUTO,
    get_ADUANA_DESTINO,
    get_CRT,
    get_DDT,
    get_DESTINATARIO,
    get_DESTINO,
    get_SEMI,
    get_TRACTOR,
    get_TRANSPORTE_CAMPO_1,
    get_TRANSPORTE_CAMPO_9,
)
from utils.utilities import (
    listar_archivos_pdf
)

def test_func(function):
    for i in archivos[:10:2]:
        pdf = PDFQuery(i)
        pdf.load(0)
        print(function(pdf))
        

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
archivos = listar_archivos_pdf('C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026')

# %%
archivos
# Out:
# ['C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR052590X.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067657S.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067725Y.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067733N.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067745Z.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067751N.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067755R.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067758U.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067764R.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067772Z.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067795V.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067831M.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067836R.pdf',
#  'C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067845R.pdf',
# ...

# %%
archivo = archivos[20]

# %%
convertir_pdf_a_xml('C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067855S.pdf', output_path='data/archivo.xml')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 convertir_pdf_a_xml('C:\\Rapha\\repos\\pdfs-to-excel-1\\data\\AG2026\\26AR067855S.pdf', output_path='data/archivo.xml')
#
# File c:\Rapha\repos\pdfs-to-excel-1\utils\utilities.py:63, in convertir_pdf_a_xml(pdf_path, output_path)
#      59 if output_path is None:
#      60     output_path = pdf_path.replace('.pdf', '.xml')
# ---> 63 pdf.tree.write(output_path, pretty_print=True, encoding="utf-8")
#      64 return output_path
#
# File src/lxml/etree.pyx:2194, in lxml.etree._ElementTree.write()
# -> 2194 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/lxml/serializer.pxi:661, in lxml.etree._tofilelike()
# --> 661 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/lxml/serializer.pxi:735, in lxml.etree._create_output_buffer()
# ...

# %%
for archivo in archivos:
    pdf = PDFQuery(archivo)
    pdf.load(0)

    print(get_TRANSPORTE_CAMPO_99(pdf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       1 for archivo in archivos:
#       2     pdf = PDFQuery(archivo)
#       3     pdf.load(0)
#       4
# ----> 5     print(get_TRANSPORTE_CAMPO_99(pdf))
#
# NameError: name 'get_TRANSPORTE_CAMPO_99' is not defined

# %%
import re
import fitz
import pandas as pd

def get_TRANSPORTE_CAMPO_9_1(archivos: list[str]):
    """_summary_

    Args:
        archivo (str): _description_

    Returns:
        _type_: _description_
    """
    
    data = []
    for archivo in archivos:
    
        pdf = fitz.open(archivo).load_page(0)
        # Load the page content as text
        page_text = pdf.get_text("text")

        texto_antes = 'CAMINH?O ORIGINAL : Nome e endereco do proprietario\n9\n'
        texto_despues = 'CAMION SUBSTITUTO : Nombre y domicilio del propietario'

        pattern = re.escape(texto_antes) + r"(.*?)" + re.escape(texto_despues)
        
        matches = re.findall(pattern, page_text, re.DOTALL)

        data.append(matches[0].split('- ')[0].strip()) if matches else None
    
    return data

get_TRANSPORTE_CAMPO_9_1(archivos)

# %%
def get_PRECINTO(pdf: PDFQuery):
    
    text  =  pdf.pq('LTTextLineHorizontal:contains("37 Numero de los precintos")').next().text()
    return text

# %%
for archivo in archivos:
    pdf = PDFQuery(archivo)
    pdf.load(0)
    print(get_PRECINTO(pdf))
# Out:
# JK86876
# JK86875
# JK86877
# JK88513
# JK88514
# JK86880
# JK88515
# JK88516
# JK88517
# JK86777
# c:\Users\rapha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pdfquery\pdfquery.py:475: SyntaxWarning: invalid escape sequence '\W'
#   k = re.sub('\W', '_', k)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 for archivo in archivos:
#       2     pdf = PDFQuery(archivo)
# ----> 3     pdf.load(0)
#       4     print(get_PRECINTO(pdf))
#
# File c:\Users\rapha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pdfquery\pdfquery.py:385, in PDFQuery.load(self, *page_numbers)
#     367 def load(self, *page_numbers):
#     368     """
#     369     Load etree and pyquery object for entire document, or given page
#     370     numbers (ints or lists). After this is called, objects are
#    (...)    383     [<LTPage>, <LTPage>]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('data/agtest1.xlsx',sheet_name='Sheet1', header=0, engine='openpyxl')
df

# hacer un grafico de torta con TRANSPORTE CAMPO 1 Y QUE SUME POR CDA UNO CANTIDAD BULTOS, ponemelo en cantidad
df.groupby('TRANSPORTE CAMPO 1')['KILOS BRUTOS'].sum().plot.pie(autopct='%1.1f%%', startangle=90, figsize=(8, 8))

# %%
def get_EXPORTADOR(pdf: PDFQuery):
    text  =  pdf.pq('LTTextLineHorizontal:contains("/ Remetente")').next().text()
    return text

# %%
data = []
for archivo in archivos:
    pdf = PDFQuery(archivo)
    pdf.load(0)
    data.append(get_DESTINATARIO(pdf))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       1 data = []
#       2 for archivo in archivos:
#       3     pdf = PDFQuery(archivo)
#       4     pdf.load(0)
# ----> 5     data.append(get_DESTINATARIO(pdf))
#       6
#
# File c:\Rapha\repos\pdfs-to-excel-1\src\scrap_pdf_AG.py:215, in get_DESTINATARIO(archivos)
#     206 """_summary_
#     207
#     208 Args:
#    (...)    212     _type_: _description_
#     213 """
#     214 data = []
# --> 215 for archivo in archivos:
#     216     pdf = fitz.open(archivo).load_page(0)
#     217     # Load the page content as text
#
# TypeError: 'PDFQuery' object is not iterable

# %%
def get_DESTINATARIO(pdf: PDFQuery):
    text  =  pdf.pq('LTTextLineHorizontal:contains("34 Destinatario / Destinatario")').next().text()
    return text

pdf = PDFQuery(archivos[1])
pdf.load(0)
get_DESTINATARIO(pdf)
# Out:
# 'SM RESINAS URUGUAY SA'

# %%
data = []
for archivo in archivos:
    
    pdf = fitz.open(archivo).load_page(0)
        # Load the page content as text
    page_text = pdf.get_text("text")

    #print(page_text)

    texto_antes = '/ Destinatario'
    texto_despues = '35 Consignatario /Consignatario'
    pattern = re.escape(texto_antes) + r"(.*)" + re.escape(texto_despues)
    matches = re.findall(pattern, page_text, re.DOTALL)

    print(matches[0].split('\n')[1]) if matches else None
    print('----------------------------------------------------------------------')
# Out:
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# SM RESINAS URUGUAY SA
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# RIO CHICO S.A.
# ----------------------------------------------------------------------
# ...

# %%
def get_DESTINATARIO(archivos: list[str]):
    data = []
    for archivo in archivos:
        
        pdf = fitz.open(archivo).load_page(0)
            # Load the page content as text
        page_text = pdf.get_text("text")

        #print(page_text)

        texto_antes = '/ Destinatario'
        texto_despues = '35 Consignatario /Consignatario'
        pattern = re.escape(texto_antes) + r"(.*)" + re.escape(texto_despues)
        matches = re.findall(pattern, page_text, re.DOTALL)

        data.append(matches[0].split('\n')[1] if matches else None)
    return data

get_DESTINATARIO(archivos)
# Out:
# ['RIO CHICO S.A.',
#  'SM RESINAS URUGUAY SA',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'RIO CHICO S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'CARGILL URUGUAY S.A.',
#  'TGL URUGUAY S.A.',
#  'TGL URUGUAY S.A.',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
#  'NUTRIMAS GRANOS S.R.L',
# ...

# %%
def check_format(pdf: PDFQuery):
    """
    Verifica si el formato del PDF es correcto.


    Args:
        pdf (PDFQuery): instancia de PDFQuery del archivo PDF.
    """
    try:
        val = bool(pdf.pq('LTTextLineHorizontal:contains("Manifiesto Internacional de Carga por Carretera / Declaracion de Transito Aduanero")'))
        return val
    except Exception as e:
        raise ValueError(f"Error al verificar el formato del PDF: {e}")
    
pdf = PDFQuery(archivos[0])
pdf.load(0)    
check_format(pdf)
# Out:
# True

# %%
df = pd.read_excel('data/DATAAAANEWLAST.xlsx')

#df['PRODUCTO'] = #LOGICA EN BASE AL EXPORTADOR
    
    #SI EL EXPORTADOR ES	LA MERCADERIA ES
    #PBBPOLISUR SOCIEDAD DE RESPONS	POLIETILENO
    #UNIPAR INDUPA SAIC	POLICLORURO DE VINILO
    #COMPA?IA MEGA SOCIEDAD ANONIMA	GAS LICUADO
    #COMPA?IA MOLINERA DEL SUR S. A	SEMOLA DE TRIGO
    #TRANSPORTADORA DE GAS DEL SUR	GAS LICUADO
    #VITERRA ARGENTINA S.A.	ACEITE / PELLETS / LECITINA
    #LA NUEVA MANERA S.A.	HARINA DE TRIGO
    #SYNGENTA	ACEITE
    #SI NO CUMPLE CON LAS ANTERIORES	INDETERMINADO
    
def logica_PRODUCTO():
    pass

df

# %%
def get_EXPORTADOR(pdf: PDFQuery):
    text  =  pdf.pq('LTTextLineHorizontal:contains("/ Remetente")').next().text()
    return text

# %%
data = []
for archivo in archivos:
    pdf = PDFQuery(archivo)
    pdf.load(0)
    exportador = (get_EXPORTADOR(pdf))
    print(exportador)
    data.append(exportador)
# Out:
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# PBBPOLISUR SOCIEDAD DE RESPONS
# BUNGE ARGENTINA S. A.
# 25 DE MAYO 501 - CP 1002 BUENOS AIRES - ARGENTINA
# BUNGE ARGENTINA S. A.
# ...

# %%
archivo = archivos[0]
pdf = PDFQuery(archivo)
pdf.load(0)
get_NACIONALIDAD_TRANSPORTE()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 4
#       1 archivo = archivos[0]
#       2 pdf = PDFQuery(archivo)
#       3 pdf.load(0)
# ----> 4 get_NACIONALIDAD_TRANSPORTE()
#
# NameError: name 'get_NACIONALIDAD_TRANSPORTE' is not defined

# %%
import pandas as pd

df = pd.DataFrame({'EXPORTADOR':data})
df['EXPORTADOR'] = df['EXPORTADOR'].str.split('\n').str[0]
df
# Out:
#                          EXPORTADOR
# 0    PBBPOLISUR SOCIEDAD DE RESPONS
# 1    PBBPOLISUR SOCIEDAD DE RESPONS
# 2    PBBPOLISUR SOCIEDAD DE RESPONS
# 3    PBBPOLISUR SOCIEDAD DE RESPONS
# 4    PBBPOLISUR SOCIEDAD DE RESPONS
# 5    PBBPOLISUR SOCIEDAD DE RESPONS
# 6    PBBPOLISUR SOCIEDAD DE RESPONS
# 7    PBBPOLISUR SOCIEDAD DE RESPONS
# 8    PBBPOLISUR SOCIEDAD DE RESPONS
# 9    PBBPOLISUR SOCIEDAD DE RESPONS
# 10   PBBPOLISUR SOCIEDAD DE RESPONS
# 11   PBBPOLISUR SOCIEDAD DE RESPONS
# 12   PBBPOLISUR SOCIEDAD DE RESPONS
# 13   PBBPOLISUR SOCIEDAD DE RESPONS
# 14   PBBPOLISUR SOCIEDAD DE RESPONS
# 15   PBBPOLISUR SOCIEDAD DE RESPONS
# 16   PBBPOLISUR SOCIEDAD DE RESPONS
# 17   PBBPOLISUR SOCIEDAD DE RESPONS
# 18   PBBPOLISUR SOCIEDAD DE RESPONS
# 19   PBBPOLISUR SOCIEDAD DE RESPONS
# 20   PBBPOLISUR SOCIEDAD DE RESPONS
# 21   PBBPOLISUR SOCIEDAD DE RESPONS
# 22   PBBPOLISUR SOCIEDAD DE RESPONS
# 23   PBBPOLISUR SOCIEDAD DE RESPONS
# 24   PBBPOLISUR SOCIEDAD DE RESPONS
# ...

# %%
df =

# %%
df = pd.DataFrame({'ARCHIVOS':archivoss,'NACIONALIDAD_TRANSPORTE_X':data})

PAISES_MERCOSUR = ['ARGENTINA', 'BRASIL', 'PARAGUAY', 'URUGUAY', 'VENEZUELA', 'CHILE', 'BOLIVIA']    

df['NACIONALIDAD_TRANSPORTE_X'] = df['NACIONALIDAD_TRANSPORTE_X'].apply(
    lambda x: next((pais for pais in PAISES_MERCOSUR if pais in x), None)
)
df_pdfs_que_no_toman_pais = df[df['NACIONALIDAD_TRANSPORTE_X'].isnull()]['ARCHIVOS']
# archivos que no tienen nacionalidad de transporte

df_pdfs_que_no_toman_pais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df = pd.DataFrame({'ARCHIVOS':archivoss,'NACIONALIDAD_TRANSPORTE_X':data})
#       2
#       3 PAISES_MERCOSUR = ['ARGENTINA', 'BRASIL', 'PARAGUAY', 'URUGUAY', 'VENEZUELA', 'CHILE', 'BOLIVIA']
#       4
#
# NameError: name 'archivoss' is not defined

# %%
for archivo in archivos:
    texto = fitz.open(archivo).load_page(0).get_text("text")
    #al texto aplicarle regex para obtener todo el texto entre '/ Nome e endereco do transportado'
    # hasta 7 Aduana, ciudad y pais de partida
    texto_antes = 'Nombre y domicilio del porteador'
    texto_despues = '7 Aduana, ciudad y pais de partida'
    pattern = re.escape(texto_antes) + r"(.*?)" + re.escape(texto_despues)
    matches = re.findall(pattern, texto, re.DOTALL)
    
    # y a matches aplicarle otro regex para obtener el pais del mercosur que encuentre en el texto
    # y si no encuentra nada, poner 'NO ENCONTRADO'
    if matches:
        pais = re.search(r'\b(?:ARGENTINA|BRASIL|PARAGUAY|URUGUAY|VENEZUELA|CHILE|BOLIVIA)\b', matches[0])
        if pais:
            print(pais.group())
        else:
            print('NO ENCONTRADO')
    else:
        print('NO ENCONTRADO')
    
    print('--------------------------------------------------')
# Out:
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# --------------------------------------------------
# ARGENTINA
# ...

# %%
def get_NACIONALIDAD_TRANSPORTE(archivos_validos: list[str]):
    data = []
    for archivo in archivos_validos:
        pdf = fitz.open(archivo).load_page(0)
        # Load the page content as text
        page_text = pdf.get_text("text")

        #print(page_text)

        texto_antes = 'Nombre y domicilio del porteador'
        texto_despues = '7 Aduana, ciudad y pais de partida'
        pattern = re.escape(texto_antes) + r"(.*?)" + re.escape(texto_despues)
        
        matches = re.findall(pattern, page_text, re.DOTALL)

        if matches:
            pais = re.search(r'\b(?:ARGENTINA|BRASIL|PARAGUAY|URUGUAY|VENEZUELA|CHILE|BOLIVIA)\b', matches[0])
            if pais:
                data.append(pais.group())
            else:
                data.append('NO ENCONTRADO')
        else:
            data.append('NO ENCONTRADO')
    return data

# %%
archivos_validos = archivos
data = get_NACIONALIDAD_TRANSPORTE(archivos_validos)
len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 archivos_validos = archivos
# ----> 2 data = get_NACIONALIDAD_TRANSPORTE(archivos_validos)
#       3 len(data)
#
# NameError: name 'get_NACIONALIDAD_TRANSPORTE' is not defined

# %%
df = pd.read_excel('data/peterlangula.xlsx', engine='openpyxl', sheet_name='Sheet1', header=0)
df.head(10)

# %%
def extraer_factura_y_orden(descripcion_mercancia: pd.Series) -> pd.DataFrame:
    """ Obtiene la factura y orden de la descripcion de mercancia

    Args:
        descripcion_mercancia (pd.Series): _description_

    Returns:
        pd.DataFrame: _description_
    """
    # Definir las expresiones regulares
    regex_factura_proforma = re.compile(r'FACTURA\s+PROFORMA\s+(\d{6,})', re.IGNORECASE)
    regex_factura_nro = re.compile(r'FACTURA\s+NRO\.\s+([A-Z0-9-]{10,})', re.IGNORECASE)
    regex_factura_exportacion = re.compile(r'FACTURA\s+(?:DE\s+)?EXPORTACION(?:\s+E)?\s+([0-9]{4,5}-[A-Z0-9]{8})', re.IGNORECASE)
    regex_fact_de_exp = re.compile(r'FACT(?:\.|URA)?\.?DE\.?EXP\.?\s*([0-9]{4}-[0-9]{8})', re.IGNORECASE)
    regex_factura_simple = re.compile(r'\b([0-9]{4}-[0-9]{8})\b')
    regex_orden = re.compile(r'ORDEN\s+(\d{9,10})', re.IGNORECASE)

    resultados = []

    for desc in descripcion_mercancia:
        if not isinstance(desc, str):
            resultados.append({'FACTURA Nº': '', 'ORDEN': ''})
            continue

        desc_upper = desc.upper()
        desc_upper = re.sub(r'SHIPMENT\s*:\s*\d+', '', desc_upper)

        factura = ''
        orden = ''
        
        # Buscar FACTURA PROFORMA
        if match := regex_factura_proforma.search(desc_upper):
            factura = match.group(1)  
            orden = match.group(1)
        else:
            match_orden = regex_orden.search(desc_upper)
            if match_orden:
                orden = match_orden.group(1)
            if match := regex_factura_exportacion.search(desc_upper):
                factura = match.group(1)
            else:
                if match := regex_factura_nro.search(desc_upper):
                    factura = match.group(1)
                else:
                    if match := regex_fact_de_exp.search(desc_upper):
                        factura = match.group(1)
                    else:
                        if match := regex_factura_simple.search(desc_upper):
                            factura = match.group(1)
        resultados.append({'FACTURA Nº': factura, 'ORDEN': orden})

    return pd.DataFrame(resultados)

def agregar_factura_y_orden(df: pd.DataFrame) -> pd.DataFrame:
    """
        Toma un DataFrame, elimina la columna 'descripcion_mercancia',
        extrae las columnas 'FACTURA Nº' y 'ORDEN' usando la función extraer_factura_y_orden,
        y las inserta en el DataFrame.

        Args:
            df (pd.DataFrame): DataFrame original.

        Returns:
            pd.DataFrame: DataFrame modificado con las columnas 'FACTURA Nº' y 'ORDEN'.
    """
    # Extraer 'FACTURA Nº' y 'ORDEN' de 'descripcion_mercancia'
    factura_orden_df = extraer_factura_y_orden(df['descripcion_mercancia'])
        
    # Eliminar la columna 'descripcion_mercancia'
    df = df.drop(columns=['descripcion_mercancia'])
        
        # Concatenar el DataFrame original con las nuevas columnas
    df = pd.concat([df, factura_orden_df], axis=1)
        
    return df

# %%
df = agregar_factura_y_orden(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rapha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7081 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.head(10)
# Out:
#                        EXPORTADOR
# 0  PBBPOLISUR SOCIEDAD DE RESPONS
# 1  PBBPOLISUR SOCIEDAD DE RESPONS
# 2  PBBPOLISUR SOCIEDAD DE RESPONS
# 3  PBBPOLISUR SOCIEDAD DE RESPONS
# 4  PBBPOLISUR SOCIEDAD DE RESPONS
# 5  PBBPOLISUR SOCIEDAD DE RESPONS
# 6  PBBPOLISUR SOCIEDAD DE RESPONS
# 7  PBBPOLISUR SOCIEDAD DE RESPONS
# 8  PBBPOLISUR SOCIEDAD DE RESPONS
# 9  PBBPOLISUR SOCIEDAD DE RESPONS

# %%
df = pd.read_excel("testing-data/data.xlsx",engine="openpyxl")

# %%
for empresa in df["TRANSPORTE CAMPO 1"]:
    
    nombre_empresa_formateado = re.sub(r'[\\/:*?"<>|]', '', empresa).strip()
    print(nombre_empresa_formateado)

# %%
empresa = 'MOYA Y COMPA?IA LIMITADA'
empresa
nombre_empresa_formateado = re.sub(r'[\\/:*?"<>|]', '', empresa).strip()
nombre_empresa_formateado
# Out:
# 'MOYA Y COMPAIA LIMITADA'

# %%
empresa

# %%
df['TRANSPORTE CAMPO 9']
# Sacar saltos de línea
descs = df['TRANSPORTE CAMPO 9']


df['TRANSPORTE CAMPO 9'] = df['TRANSPORTE CAMPO 9'].str.replace('\n', '', regex=True)# Compilar el patrón regex
patron = re.compile(r'(?: & -|-).*', re.IGNORECASE)

df['TRANSPORTE CAMPO 9'] = df['TRANSPORTE CAMPO 9'].str.replace(patron, '', regex=True).str.strip()
# Reemplazar todo lo que coincide con el patrón
df['TRANSPORTE CAMPO 9']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rapha\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7081 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df_mic_y_tp1 = df[['TRANSPORTE CAMPO 1', 'MIC - DTA']]
df_mic_y_tp1

# %%
empresa = 'CARLOS PATRON S.A.'
lista_mics_de_empresa = list(df[df["TRANSPORTE CAMPO 1"] == empresa]['MIC - DTA'])
lista_mics_de_empresa

# %%
path = 'D:/Moggia/pdfs-to-excel/testing-data/03 MARZO 2025'
files_with_path = [os.path.join(path, file) for file in list(os.walk(path))[0][2] if file.endswith('.pdf')]
files_with_path

# %%
empresa

lista_mics_de_empresa = list(df[df["TRANSPORTE CAMPO 1"] == empresa]['MIC - DTA'])
lista_mics_de_empresa

# %%
rutas_filtradas = [ruta for ruta in files_with_path if any(mic in ruta for mic in lista_mics_de_empresa)]
rutas_filtradas

# %%
# 1. Librerías necesarias
import os
import shutil
import pandas as pd
import re
from fuzzywuzzy import fuzz, process



# 2. Función para estandarizar razones sociales
def estandarizar_razon_social(razon_social):
    if pd.isna(razon_social):
        return ""
    razon = razon_social.upper()
    razon = razon.replace(",", "")
    razon = razon.replace(".", "")
    razon = re.sub(r'\bSOCIEDAD\s+ANONIMA\b', 'SA', razon)
    razon = re.sub(r'\bSOCIEDAD\s+ANÓNIMA\b', 'SA', razon)
    razon = re.sub(r'\bS\s*A\b', 'SA', razon)
    razon = re.sub(r'\bSOCIEDAD\s+RESPONSABILIDAD\s+LIMITADA\b', 'SRL', razon)
    razon = re.sub(r'\bS\s*R\s*L\b', 'SRL', razon)
    razon = re.sub(r'\s+', ' ', razon).strip()
    return razon

# 3. Cargar datos
data = pd.read_excel("testing-data/AG-test/AG.xlsx", engine="openpyxl")
df = data[["TRANSPORTE CAMPO 1"]].rename(columns={"TRANSPORTE CAMPO 1": "Razon Social"})

# 4. Estandarizar razones sociales
df["Razon Social Estandarizada"] = df["Razon Social"].apply(estandarizar_razon_social)

# 5. Agrupar usando fuzzy matching
razones_unicas = []

# Threshold de similitud: 90%
threshold = 85

for razon in df["Razon Social Estandarizada"]:
    match = process.extractOne(razon, razones_unicas, scorer=fuzz.token_sort_ratio)
    
    if match is None or match[1] < threshold:
        razones_unicas.append(razon)
    else:
        # Si encuentra una similar, la consideramos ya incluida
        continue

# 6. Asignar a qué grupo pertenece cada razón social
def asignar_grupo(razon, razones_unicas, threshold=90):
    match = process.extractOne(razon, razones_unicas, scorer=fuzz.partial_ratio)
    if match and match[1] >= threshold:
        return match[0]
    else:
        return razon

df["Grupo Razon Social"] = df["Razon Social Estandarizada"].apply(lambda x: asignar_grupo(x, razones_unicas))



# 8. Eliminar duplicados finales
df_unico = df.sort_values("Razon Social").groupby("Grupo Razon Social", as_index=False).first()[["Razon Social"]]


# Mostrar solo una vez cada razón social final
df_unico
# Out:
# c:\Users\rapha\AppData\Local\Programs\Python\Python313\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[57], line 26
#      22     razon = re.sub(r'\s+', ' ', razon).strip()
#      23     return razon
#      24
#      25 # 3. Cargar datos
# ---> 26 data = pd.read_excel("testing-data/AG-test/AG.xlsx", engine="openpyxl")
#      27 df = data[["TRANSPORTE CAMPO 1"]].rename(columns={"TRANSPORTE CAMPO 1": "Razon Social"})
#      28
#      29 # 4. Estandarizar razones sociales
#
# ...

# %%
df = pd.read_excel("testing-data/AG-test/AG.xlsx", engine="openpyxl")
empresas = list(df["TRANSPORTE CAMPO 1"].unique())

df.tail()

# %%
list(empresas)

# %%
import pandas as pd
from rapidfuzz import process, fuzz

df_empresa_nombes = pd.DataFrame({'original': empresas})

nombres_base = []
mapeo_estandar = {}
umbral = 85  # Nivel de similitud


for nombre in df_empresa_nombes['original'].unique():
    match = process.extractOne(nombre, nombres_base, scorer=fuzz.token_sort_ratio)
    
    if match and match[1] >= umbral:
        mapeo_estandar[nombre] = match[0]
    else:
        mapeo_estandar[nombre] = nombre
        nombres_base.append(nombre)

# Aplicar mapeo al DataFrame
df_empresa_nombes['empresa_estandarizada'] = df_empresa_nombes['original'].map(mapeo_estandar)

# Ver resultado
df_empresa_nombes['empresa_estandarizada'].unique()

# %%
from rapidfuzz import process, fuzz
import pandas as pd

def estandarizar_empresas(columna_transporte):
    """
    Función que estandariza los nombres de empresas en la columna 'TRANSPORTE CAMPO 1'.

    Args:
        columna_transporte (pd.Series): Columna con los nombres originales de las empresas.

    Returns:
        pd.DataFrame: DataFrame con las columnas 'original' y 'empresa_estandarizada'.
    """
    nombres_base = []
    mapeo_estandar = {}
    umbral = 85  # Nivel de similitud

    for nombre in columna_transporte.unique():
        match = process.extractOne(nombre, nombres_base, scorer=fuzz.token_sort_ratio)
        
        if match and match[1] >= umbral:
            mapeo_estandar[nombre] = match[0]
        else:
            mapeo_estandar[nombre] = nombre
            nombres_base.append(nombre)

    # Crear el DataFrame con los resultados
    df_resultado = pd.DataFrame({
        'original': columna_transporte,
        'empresa_estandarizada': columna_transporte.map(mapeo_estandar)
    })

    return df_resultado

# %%
estandarizar_empresas(df['TRANSPORTE CAMPO 1'])

# %% [markdown]
# ### DETALLE DE OPERACIONES

# %%
from openpyxl import Workbook
from openpyxl.drawing.image import Image
from openpyxl.styles import Alignment, Font, PatternFill, Border, Side
from openpyxl.utils import get_column_letter

# Crear el Workbook
wb = Workbook()
ws = wb.active
ws.title = "Detalle Operaciones"

# Fondo blanco
white_fill = PatternFill(start_color="FFFFFF", end_color="FFFFFF", fill_type="solid")



# Pintar fondo blanco de A1 a E12
for row in range(1, 13):
    for col in range(1, 6):
        cell = ws.cell(row=row, column=col)
        cell.fill = white_fill

# Borde grueso del recuadro A6:E12
thick_side = Side(border_style="thick")
for row in range(6, 13):
    for col in range(1, 6):
        col_letter = get_column_letter(col)
        ws[f"{col_letter}{row}"].border = Border(
            top=thick_side if row == 6 else None,
            bottom=thick_side if row == 12 else None,
            left=thick_side if col == 1 else None,
            right=thick_side if col == 5 else None
        )

# Título principal
ws.merge_cells('A7:E7')
ws['A7'] = 'DETALLE DE OPERACIONES'
ws['A7'].alignment = Alignment(horizontal='center', vertical='center')
ws['A7'].font = Font(size=16, bold=True, underline='single')
ws['A7'].fill = white_fill

# Mes y Año
ws['A8'] = 'MES:'
ws['A8'].alignment = Alignment(horizontal='right', vertical='center')
ws['A8'].font = Font(bold=True)
ws['A8'].fill = white_fill

ws['B8'] = ''  # Espacio para completar el mes
ws['B8'].fill = white_fill

ws['D8'] = 'AÑO:'
ws['D8'].alignment = Alignment(horizontal='right', vertical='center')
ws['D8'].font = Font(bold=True)
ws['D8'].fill = white_fill

ws['E8'] = ''  # Espacio para completar el año
ws['E8'].fill = white_fill

# Texto largo
texto_largo = "Detalle de las operaciones en las que hemos actuado en carácter de Agentes de Transporte"
texto_corto = "Aduanero de la firma:"

ws.merge_cells('A9:E9')
ws['A9'] = texto_largo
ws['A9'].alignment = Alignment(horizontal='left', vertical='center', wrap_text=True)
ws['A9'].font = Font(size=11)
ws['A9'].fill = white_fill

# Aduanero de la firma
ws['A10'] = texto_corto
ws['A10'].alignment = Alignment(horizontal='left', vertical='center')
ws['A10'].font = Font(size=11)
ws['A10'].fill = white_fill

ws['B10'] = ''  # Espacio para nombre de firma
ws['B10'].fill = white_fill

# Total de unidades
ws['A11'] = "Total de unidades:"
ws['A11'].alignment = Alignment(horizontal='left', vertical='center')
ws['A11'].font = Font(size=11)
ws['A11'].fill = white_fill

ws['B11'] = ''  # Espacio para completar total
ws['B11'].fill = white_fill

# Encabezados de tabla (fila 13)
column_headers = ['FECHA', 'MIC-DTA', 'D.D.T.', 'ORDEN', 'FACTURA N°']
header_fill = PatternFill(start_color="CCFFFF", end_color="CCFFFF", fill_type="solid")  # Celeste claro

for col_num, header in enumerate(column_headers, start=1):
    col_letter = get_column_letter(col_num)
    cell = ws[f'{col_letter}13']
    cell.value = header
    cell.alignment = Alignment(horizontal='center', vertical='center')
    cell.font = Font(bold=True)
    cell.fill = header_fill
    cell.border = Border(
        left=Side(style='thin'),
        right=Side(style='thin'),
        top=Side(style='thin'),
        bottom=Side(style='thin')
    )

# Los datos vienen por parámetro
datos = []

# Borde fino
thin_border = Border(
    left=Side(style='thin'),
    right=Side(style='thin'),
    top=Side(style='thin'),
    bottom=Side(style='thin')
)

# Escribir los datos a partir de la fila 14
for fila_idx, fila_dato in enumerate(datos, start=14):
    for col_idx, valor in enumerate(fila_dato, start=1):
        cell = ws.cell(row=fila_idx, column=col_idx)
        cell.value = valor
        cell.alignment = Alignment(horizontal='center', vertical='center')
        cell.border = thin_border
        cell.fill = white_fill
    ws.row_dimensions[fila_idx].height = 20

# Ajustar ancho de columnas
column_widths = [20, 16, 18, 16, 16]
for i, width in enumerate(column_widths, start=1):
    ws.column_dimensions[get_column_letter(i)].width = width

# Centrado de impresión y ajustes
ws.page_setup.horizontalCentered = True
ws.page_setup.fitToWidth = 1
ws.page_setup.fitToHeight = 0

# Actualizar área de impresión
ultima_fila = 13 + len(datos)
ws.print_area = f"A1:E{ultima_fila}"

# Guardar
wb.save('plantilla_detalle_operaciones.xlsx')

# %%
import openpyxl
from openpyxl import load_workbook



# Cargar el libro de trabajo existente
wb = load_workbook('assets/plantilla_detalle_operaciones.xlsx')

# cargar la hoja activa
ws = wb.active
# 1 paso
mes = 'marzo'

ws['B8'] = mes
ws['B8'].alignment = Alignment(horizontal='left', vertical='center')


# 2 paso
anio = 2025

ws['E8'] = anio
ws['E8'].alignment = Alignment(horizontal='left', vertical='center')

nombre_firma = 'PEPE 123'

ws['B10'] = ''

# 3 paso (meter los datos)
wb.save('assets/plantilla_detalle_operaciones_actualizada.xlsx')





# esto va despues de ingresar los datos al excel
# 4 paso
total_unidades = 15
ws['B11'] = total_unidades
ws['B11'].alignment = Alignment(horizontal='left', vertical='center')

# %%
import shutil

df = pd.read_excel('testing-data/AG-test2/AG.xlsx', engine='openpyxl')
# Crear una copia del archivo existente

ruta_original = 'assets/plantilla_detalle_operaciones.xlsx'
ruta_copia = 'assets/plantilla_detalle_operaciones_copia.xlsx'
shutil.copy(ruta_original, ruta_copia)

# Crear un nuevo archivo basado en la copia
with pd.ExcelWriter(ruta_copia, engine='openpyxl', mode='a', if_sheet_exists='overlay') as writer:
    df[['FECHA CARGA', 'MIC - DTA', 'D.D.T', 'ORDEN', 'FACTURA Nº']].to_excel(writer, sheet_name='Detalle Operaciones', index=False, startrow=13, startcol=0, header=False)

# %%
import os
import shutil
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Alignment

import os
from os.path import abspath
import shutil
import sys
import win32com.client 
from shutil import rmtree
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Alignment
from xlwings import Book

def get_asset_path(relative_path):
    """Obtiene la ruta correcta del archivo, ya sea en desarrollo o en el ejecutable."""
    try:
        # Cuando se ejecuta como ejecutable empaquetado
        base_path = sys._MEIPASS
    except AttributeError:
        # Cuando se ejecuta como script en desarrollo
        base_path = os.path.abspath(".")
    return os.path.join(base_path, relative_path)

def main_process_detalle_operacion(ruta_excel_base, ruta_destino, excel_datos, anio, mes):
    """
    Genera un Excel con detalle de operaciones a partir de una plantilla.

    Args:
        ruta_excel_base (str): Ruta de la plantilla base (siempre será 'assets/plantilla_detalle_operaciones.xlsx').
        ruta_destino (str): Carpeta donde se guardará el archivo resultante.
        excel_datos (str): Ruta del archivo Excel con los datos.
        anio (int): Año a insertar.
        mes (str): Mes a insertar.
    """
    ruta_excel_base = get_asset_path(ruta_excel_base)

    # Crear nombre del nuevo archivo
    nombre_empresa = os.path.basename(excel_datos).split('AG-')[1].split('.xlsx')[0]
    nombre_archivo = "Detalle Operaciones " + nombre_empresa + ".xlsx"
    ruta_final = os.path.join(ruta_destino, nombre_archivo)

    # Copiar plantilla a destino
    shutil.copy(ruta_excel_base, ruta_final)

    # Abrir archivo copiado
    wb = load_workbook(ruta_final)
    wb.template = False
    ws = wb.active
    # Insertar mes y año
    ws['B8'] = mes
    ws['B8'].alignment = Alignment(horizontal='left', vertical='center')

    ws['E8'] = anio
    ws['E8'].alignment = Alignment(horizontal='left', vertical='center')

    # Nombre de la firma (harcodeado por ahora)
    ws['B10'] = nombre_empresa
    ws['B10'].alignment = Alignment(horizontal='left', vertical='center')

    # Leer datos desde el archivo Excel de datos
    df = pd.read_excel(excel_datos, engine='openpyxl')
    df_final = df.loc[:, ['FECHA CARGA', 'MIC - DTA', 'D.D.T', 'ORDEN', 'FACTURA Nº']]
    df_final['FECHA CARGA'] = pd.to_datetime(df_final['FECHA CARGA'], dayfirst=True, errors='coerce')
    # Ordenar por la columna 'FECHA CARGA' de menor a mayor
    df_final = df_final.sort_values(by='FECHA CARGA', ascending=True).reset_index(drop=True)
    df_final['FECHA CARGA'] = df_final['FECHA CARGA'].dt.strftime('%d/%m/%Y')

    # Insertar total de unidades
    total_unidades = len(df_final)
    ws['B11'] = total_unidades
    ws['B11'].alignment = Alignment(horizontal='left', vertical='center')

    # Insertar datos desde fila 14 (índice 13)
    for i, row in df_final.iterrows():
        for j, campo in enumerate(['FECHA CARGA', 'MIC - DTA', 'D.D.T', 'ORDEN', 'FACTURA Nº']):
            ws.cell(row=14 + i, column=1 + j, value=row[campo])

    # Guardar
    wb.save(ruta_final)
    
    wb = Book(ruta_final)
    ws =  wb.sheets[0]
    img = os.path.abspath('assets/imagen.jpg')
    ws.pictures.add(
        img,
        top=ws.range('A1').top,
        left=ws.range('A1').left,
        width=ws.range('E5').left + ws.range('E5').width - ws.range('A1').left,
        height=ws.range('E5').top + ws.range('E5').height - ws.range('A1').top
)
    print(f"Archivo guardado en: {ruta_final}")

# %%
main_process_detalle_operacion(
    'assets/plantilla_detalle_operaciones_temp1.xlsx', 
    'testing-data/', 
    'testing-data/AGtestDetalle/TRANSPORTES GRACA SA/AG-TRANSPORTES GRACA SA.xlsx', 
    2025, 
    'marzo'
)

# %%
df_test = pd.read_excel('testing-data/AGtestDetalle/TRANSPORTES GRACA SA/AG-TRANSPORTES GRACA SA.xlsx', engine='openpyxl')
df_test['FECHA CARGA'].sort_values(ascending=True)

# %%
import pandas as pd
# Convertir la columna 'FECHA CARGA' a formato datetime
df = pd.read_excel('testing-data/AGtestDetalle/TRANSPORTES GRACA SA/AG-TRANSPORTES GRACA SA.xlsx', engine='openpyxl')
df['FECHA CARGA'] = pd.to_datetime(df['FECHA CARGA'], dayfirst=True, errors='coerce')

# Obtener el mes y el año únicos
mes = df['FECHA CARGA'].dt.month.unique()[0]
anio = df['FECHA CARGA'].dt.year.unique()[0]

meses = [
        "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
        "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
        ]

mes = meses[mes - 1]  
mes, anio
